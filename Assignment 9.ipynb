# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist

text = """Books are a source of knowledge, imagination, and inspiration. They take readers on journeys across time, space, and emotions. From fiction to nonfiction, books help us understand the world and ourselves better. Reading regularly improves vocabulary, focus, and critical thinking. Whether for learning or leisure, books are lifelong companions."""

# 1. Lowercase and remove punctuation
text_lower = text.lower().translate(str.maketrans('', '', string.punctuation))

# 2. Tokenize
sent_tokens = sent_tokenize(text_lower)
word_tokens = word_tokenize(text_lower)

# 3. Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in word_tokens if word not in stop_words]

# 4. Word frequency (excluding stopwords)
freq_dist = FreqDist(filtered_words)
print("Word Frequency Distribution:")
print(freq_dist.most_common())
# Out:
# Word Frequency Distribution:
# [('books', 3), ('source', 1), ('knowledge', 1), ('imagination', 1), ('inspiration', 1), ('take', 1), ('readers', 1), ('journeys', 1), ('across', 1), ('time', 1), ('space', 1), ('emotions', 1), ('fiction', 1), ('nonfiction', 1), ('help', 1), ('us', 1), ('understand', 1), ('world', 1), ('better', 1), ('reading', 1), ('regularly', 1), ('improves', 1), ('vocabulary', 1), ('focus', 1), ('critical', 1), ('thinking', 1), ('whether', 1), ('learning', 1), ('leisure', 1), ('lifelong', 1), ('companions', 1)]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\96597\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\96597\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\96597\AppData\Roaming\nltk_data...
# ...

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, WordNetLemmatizer

porter = PorterStemmer()
lancaster = LancasterStemmer()
lemmatizer = WordNetLemmatizer()

# Apply stemming
porter_stemmed = [porter.stem(w) for w in filtered_words]
lancaster_stemmed = [lancaster.stem(w) for w in filtered_words]

# Apply lemmatization
lemmatized = [lemmatizer.lemmatize(w) for w in filtered_words]

print("\nPorter Stemmer:", porter_stemmed)
print("Lancaster Stemmer:", lancaster_stemmed)
print("Lemmatized:", lemmatized)
# Out:
# Porter Stemmer: ['book', 'sourc', 'knowledg', 'imagin', 'inspir', 'take', 'reader', 'journey', 'across', 'time', 'space', 'emot', 'fiction', 'nonfict', 'book', 'help', 'us', 'understand', 'world', 'better', 'read', 'regularli', 'improv', 'vocabulari', 'focu', 'critic', 'think', 'whether', 'learn', 'leisur', 'book', 'lifelong', 'companion']
# Lancaster Stemmer: ['book', 'sourc', 'knowledg', 'imagin', 'inspir', 'tak', 'read', 'journey', 'across', 'tim', 'spac', 'emot', 'fict', 'nonfict', 'book', 'help', 'us', 'understand', 'world', 'bet', 'read', 'regul', 'improv', 'vocab', 'foc', 'crit', 'think', 'wheth', 'learn', 'leis', 'book', 'lifelong', 'comp']
# ...

# %%
import re

# Original text
original_text = text

# a. Words > 5 letters
long_words = re.findall(r'\b\w{6,}\b', original_text)

# b. Extract numbers
numbers = re.findall(r'\b\d+\b', original_text)

# c. Capitalized words
capitalized = re.findall(r'\b[A-Z][a-z]*\b', original_text)

# d. Alphabet-only words
alpha_words = re.findall(r'\b[a-zA-Z]+\b', original_text)

# e. Words starting with vowels
vowel_words = [word for word in alpha_words if word.lower().startswith(('a', 'e', 'i', 'o', 'u'))]

print("\nWords > 5 letters:", long_words)
print("Numbers:", numbers)
print("Capitalized words:", capitalized)
print("Alphabet-only words:", alpha_words)
print("Words starting with vowels:", vowel_words)
# Out:
# Words > 5 letters: ['source', 'knowledge', 'imagination', 'inspiration', 'readers', 'journeys', 'across', 'emotions', 'fiction', 'nonfiction', 'understand', 'ourselves', 'better', 'Reading', 'regularly', 'improves', 'vocabulary', 'critical', 'thinking', 'Whether', 'learning', 'leisure', 'lifelong', 'companions']
# Numbers: []
# Capitalized words: ['Books', 'They', 'From', 'Reading', 'Whether']
# Alphabet-only words: ['Books', 'are', 'a', 'source', 'of', 'knowledge', 'imagination', 'and', 'inspiration', 'They', 'take', 'readers', 'on', 'journeys', 'across', 'time', 'space', 'and', 'emotions', 'From', 'fiction', 'to', 'nonfiction', 'books', 'help', 'us', 'understand', 'the', 'world', 'and', 'ourselves', 'better', 'Reading', 'regularly', 'improves', 'vocabulary', 'focus', 'and', 'critical', 'thinking', 'Whether', 'for', 'learning', 'or', 'leisure', 'books', 'are', 'lifelong', 'companions']
# ...

# %%
# Custom tokenizer
def custom_tokenizer(text):
    text = re.sub(r'[^\w\s\-\']', '', text) 
    tokens = re.findall(r"\b(?:[A-Za-z]+(?:-[A-Za-z]+)*|\d+(?:\.\d+)?)\b", text)
    return tokens

# Sample extended text
custom_text = """You can email us at example@mail.com or visit https://www.example.com. Call us at 123-456-7890 or +91 9876543210. Our AI-powered platform is state-of-the-art and isn't slowing down."""

tokens = custom_tokenizer(custom_text)

# Regex substitutions
cleaned = re.sub(r'\b[\w.-]+?@\w+?\.\w+?\b', '<EMAIL>', custom_text)
cleaned = re.sub(r'https?://\S+|www\.\S+', '<URL>', cleaned)
cleaned = re.sub(r'\b(\+91\s\d{10}|\d{3}-\d{3}-\d{4})\b', '<PHONE>', cleaned)

print("\nCustom Tokens:", tokens)
print("Cleaned Text:", cleaned)
# Out:
# Custom Tokens: ['You', 'can', 'email', 'us', 'at', 'examplemailcom', 'or', 'visit', 'httpswwwexamplecom', 'Call', 'us', 'at', '123', '456', '7890', 'or', '91', '9876543210', 'Our', 'AI-powered', 'platform', 'is', 'state-of-the-art', 'and', 'isn', 't', 'slowing', 'down']
# Cleaned Text: You can email us at <EMAIL> or visit <URL> Call us at <PHONE> or +91 9876543210. Our AI-powered platform is state-of-the-art and isn't slowing down.
